# %%
# !python run.py --wandb_prj extend-knn --model GloCOM --global_dir umap_globalcluster200 --num_topics 100 --device cuda:0\
                          --seed 254 --dropout 0.0 --aug_coef 5  --prior_var 0.01 \
                          --weight_loss_ECR 90 --data_dir data/GoogleNews
# Out:
# Folder created: results/GloCOM/2025-03-17_18-51-08
# .. STARTING ..
# Namespace(model='GloCOM', wandb_prj='extend-knn', aug_coef=5.0, prior_var=0.01, weight_loss_ECR=90.0, dropout=0.0, seed=254, epochs=200, device='cuda:0', batch_size=200, lr=0.002, lr_scheduler=None, lr_step_size=125, data_dir='data/GoogleNews', global_dir='umap_globalcluster200', num_top_word=15, num_topics=100)
# data_size:  11019
# vocab_size:  3473
# average length: 5.753
# ...
# 100%|█████████████████████████████████████████| 200/200 [10:57<00:00,  3.29s/it]
# Topic 0: animation undefeated nuke voltage billionaire activist motion settle ruled install adrian ceo tivo armchair r
# Topic 1: revenue expectation boosted quarterly enterprise hewlett packard earnings pickup hpq hp corporate infoblox analog turnaround
# Topic 2: like aspirin vaccinated ann contraceptive vitamin elder magical medicine design smart younger enables teach browser
# ...

# %%
# !python run.py --wandb_prj glocom --model GloCOM --num_topics 100 --device cuda:1\
                          --seed 0 --aug_coef 0.1 --prior_var 0.1 \
                          --weight_loss_ECR 10 --data_dir data/GoogleNews
# Out:
# Folder created: results/GloCOM/2025-02-25_13-38-40
# .. STARTING ..
# Namespace(model='GloCOM', wandb_prj='glocom', aug_coef=0.1, prior_var=0.1, weight_loss_ECR=10.0, seed=0, epochs=200, device='cuda:1', batch_size=200, lr=0.002, lr_scheduler=None, lr_step_size=125, data_dir='data/GoogleNews', num_top_word=15, num_topics=100)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# wandb: Run data is saved locally in /mnt/tungns/GloCOM-extend/Extend/wandb/run-20250225_133841-h039catu
# ...
